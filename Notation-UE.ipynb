# %%
som_1=0
coe_1=0
moy_1=0

for i in range (101 , 116):
    note=float(input("Donnez moi la note de la ressources R{}".format(i)))
    coeff=float(input("Donnez moi le coefficient de la ressources R{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff
for i in range (11 , 13):
    note=float(input("Donnez moi la note de la SAE SAE{}".format(i)))
    coeff=float(input("Donnez moi le coefficient de la SAE SAE{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff
moy_1=som_1/coe_1
print(f"{moy_1:.2f}")

som_2=0
coe_2=0
moy_2=0

for i in range (101 , 104):
    note=float(input("Donnez moi la note de la ressources R{}".format(i)))
    coeff=float(input("Donnez moi le coefficient de la ressources R{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff
for i in range (11 , 13):
    note=float(input("Donnez moi la note de la SAE SAE{}".format(i)))
    coeff=float(input("Donnez moi le coefficient de la SAE SAE{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff
moy_1=som_1/coe_1
print(f"{moy_1:.2f}")
# Out:
# Donnez moi la note de la ressources R101 12
# Donnez moi le coefficient de la ressources R101 10
# Donnez moi la note de la ressources R102 7
# Donnez moi le coefficient de la ressources R102 7
# Donnez moi la note de la ressources R103 14
# Donnez moi le coefficient de la ressources R103 7
# Donnez moi la note de la SAE SAE11 14
# Donnez moi le coefficient de la SAE SAE11 20
# Donnez moi la note de la SAE SAE12 9
# Donnez moi le coefficient de la SAE SAE12 20
# 11.36

# %%
print(f"{moy_1:.2f}")
# Out:
# 12.52
